# %%
import mysql.connector

# %% [markdown]
# #### 1. Create Connection

# %%
mydb = mysql.connector.connect(
    host='192.168.35.159', 
    port=3306,
    user='newrandom', 
    password=input()
    )

# %% [markdown]
# #### Create Connection 예제 1
# - Local Database 연결

# %%
local = mysql.connector.connect(
    host='localhost',
    user = 'root',
    password=input()

)

# %% [markdown]
# #### Create Connection 예제2
# - AWS RDS(database -1) 연결

# %%
remote = mysql.connector.connect(
    host = 'END POINT',
    port = 3306,
    user = 'root',
    password = 'password'       # AWS 접속 시 해당 문구들 변경할 것.
)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/miniforge3/envs/practice/lib/python3.10/site-packages/mysql/connector/network.py:547, in MySQLTCPSocket.open_connection(self)
#     546 try:
# --> 547     addrinfos = socket.getaddrinfo(self.server_host,
#     548                                    self.server_port,
#     549                                    0, socket.SOCK_STREAM,
#     550                                    socket.SOL_TCP)
#     551     # If multiple results we favor IPv4, unless IPv6 was forced.
#
# File ~/miniforge3/envs/practice/lib/python3.10/socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# /Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb 셀 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000009?line=0'>1</a> remote = mysql.connector.connect(
#       <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000009?line=1'>2</a>     host = 'END POINT',
#       <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000009?line=2'>3</a>     port = 3306,
#       <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000009?line=3'>4</a>     user = 'root',
#       <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000009?line=4'>5</a>     password = 'password'       # AWS 접속 시 해당 문구들 변경할 것.
#       <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000009?line=5'>6</a> )
#
# File ~/miniforge3/envs/practice/lib/python3.10/site-packages/mysql/connector/__init__.py:273, in connect(*args, **kwargs)
#     271 if HAVE_CEXT and not use_pure:
#     272     return CMySQLConnection(*args, **kwargs)
# --> 273 return MySQLConnection(*args, **kwargs)
#
# File ~/miniforge3/envs/practice/lib/python3.10/site-packages/mysql/connector/connection.py:116, in MySQLConnection.__init__(self, *args, **kwargs)
#     114 if kwargs:
#     115     try:
# --> 116         self.connect(**kwargs)
#     117     except:
#     118         # Tidy-up underlying socket on failure
#     119         self.close()
#
# File ~/miniforge3/envs/practice/lib/python3.10/site-packages/mysql/connector/abstracts.py:1052, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1049     self.config(**kwargs)
#    1051 self.disconnect()
# -> 1052 self._open_connection()
#    1053 # Server does not allow to run any other statement different from ALTER
#    1054 # when user's password has been expired.
#    1055 if not self._client_flags & ClientFlag.CAN_HANDLE_EXPIRED_PASSWORDS:
#
# File ~/miniforge3/envs/practice/lib/python3.10/site-packages/mysql/connector/connection.py:494, in MySQLConnection._open_connection(self)
#     492 self._socket = self._get_connection()
#     493 try:
# --> 494     self._socket.open_connection()
#     495     self._do_handshake()
#     496     self._do_auth(self._user, self._password,
#     497                   self._database, self._client_flags, self._charset_id,
#     498                   self._ssl, self._conn_attrs)
#
# File ~/miniforge3/envs/practice/lib/python3.10/site-packages/mysql/connector/network.py:565, in MySQLTCPSocket.open_connection(self)
#     563         addrinfo = addrinfos[0]
#     564 except IOError as err:
# --> 565     raise errors.InterfaceError(
#     566         errno=2003, values=(self.get_address(), _strioerror(err)))
#     567 else:
#     568     (self._family, socktype, proto, _, sockaddr) = addrinfo
#
# InterfaceError: 2003: Can't connect to MySQL server on '%-.100s:%u' (%s) (Warning: %u format: a real number is required, not str)

# %% [markdown]
# #### Close Database

# %%
local.close()

# %%
mydb.close()

# %% [markdown]
# #### Create Connection 예제 1
# - Local MySQL 의 zerobase 에 연결

# %%
local = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password = input(),
    database = 'zerobase'       # zerobase database가 있을 때 가능
)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb 셀 12 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000016?line=0'>1</a> local = mysql.connector.connect(
#       <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000016?line=1'>2</a>     host = 'localhost',
#       <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000016?line=2'>3</a>     user = 'root',
#       <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000016?line=3'>4</a>     password = input(),
#       <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000016?line=4'>5</a>     database = 'zerobase'
#       <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000016?line=5'>6</a> )
#
# File ~/miniforge3/envs/practice/lib/python3.10/site-packages/mysql/connector/__init__.py:273, in connect(*args, **kwargs)
#     271 if HAVE_CEXT and not use_pure:
#     272     return CMySQLConnection(*args, **kwargs)
# --> 273 return MySQLConnection(*args, **kwargs)
#
# File ~/miniforge3/envs/practice/lib/python3.10/site-packages/mysql/connector/connection.py:116, in MySQLConnection.__init__(self, *args, **kwargs)
#     114 if kwargs:
#     115     try:
# --> 116         self.connect(**kwargs)
#     117     except:
#     118         # Tidy-up underlying socket on failure
#     119         self.close()
#
# File ~/miniforge3/envs/practice/lib/python3.10/site-packages/mysql/connector/abstracts.py:1052, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1049     self.config(**kwargs)
#    1051 self.disconnect()
# -> 1052 self._open_connection()
#    1053 # Server does not allow to run any other statement different from ALTER
#    1054 # when user's password has been expired.
#    1055 if not self._client_flags & ClientFlag.CAN_HANDLE_EXPIRED_PASSWORDS:
#
# File ~/miniforge3/envs/practice/lib/python3.10/site-packages/mysql/connector/connection.py:496, in MySQLConnection._open_connection(self)
#     494 self._socket.open_connection()
#     495 self._do_handshake()
# --> 496 self._do_auth(self._user, self._password,
#     497               self._database, self._client_flags, self._charset_id,
#     498               self._ssl, self._conn_attrs)
#     499 self.set_converter_class(self._converter_class)
#     500 if self._client_flags & ClientFlag.COMPRESS:
#
# File ~/miniforge3/envs/practice/lib/python3.10/site-packages/mysql/connector/connection.py:242, in MySQLConnection._do_auth(self, username, password, database, client_flags, charset, ssl_options, conn_attrs)
#     234 packet = self._protocol.make_auth(
#     235     handshake=self._handshake,
#     236     username=username, password=password, database=database,
#    (...)
#     239     auth_plugin=self._auth_plugin,
#     240     conn_attrs=conn_attrs)
#     241 self._socket.send(packet)
# --> 242 self._auth_switch_request(username, password)
#     244 if not (client_flags & ClientFlag.CONNECT_WITH_DB) and database:
#     245     self.cmd_init_db(database)
#
# File ~/miniforge3/envs/practice/lib/python3.10/site-packages/mysql/connector/connection.py:288, in MySQLConnection._auth_switch_request(self, username, password)
#     286     return self._handle_mfa(packet)
#     287 elif packet[4] == 255:
# --> 288     raise errors.get_exception(packet)
#     289 return None
#
# ProgrammingError: 1049 (42000): Unknown database 'zerobase'

# %%
local.close()

# %% [markdown]
# - AWS RDS(database-1)의 zerobase 에 연결

# %%
remote = mysql.connector.connect(
    host = 'ENDPOINT',
    port=  3306,
    user = 'admin', 
    password = 'zerobase',
    database = 'zerobase'
)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/miniforge3/envs/practice/lib/python3.10/site-packages/mysql/connector/network.py:547, in MySQLTCPSocket.open_connection(self)
#     546 try:
# --> 547     addrinfos = socket.getaddrinfo(self.server_host,
#     548                                    self.server_port,
#     549                                    0, socket.SOCK_STREAM,
#     550                                    socket.SOL_TCP)
#     551     # If multiple results we favor IPv4, unless IPv6 was forced.
#
# File ~/miniforge3/envs/practice/lib/python3.10/socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# /Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb 셀 15 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000020?line=0'>1</a> remote = mysql.connector.connect(
#       <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000020?line=1'>2</a>     host = 'ENDPOINT',
#       <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000020?line=2'>3</a>     port=  3306,
#       <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000020?line=3'>4</a>     user = 'admin',
#       <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000020?line=4'>5</a>     password = 'zerobase',
#       <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000020?line=5'>6</a>     database = 'zerobase'
#       <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000020?line=6'>7</a> )
#
# File ~/miniforge3/envs/practice/lib/python3.10/site-packages/mysql/connector/__init__.py:273, in connect(*args, **kwargs)
#     271 if HAVE_CEXT and not use_pure:
#     272     return CMySQLConnection(*args, **kwargs)
# --> 273 return MySQLConnection(*args, **kwargs)
#
# File ~/miniforge3/envs/practice/lib/python3.10/site-packages/mysql/connector/connection.py:116, in MySQLConnection.__init__(self, *args, **kwargs)
#     114 if kwargs:
#     115     try:
# --> 116         self.connect(**kwargs)
#     117     except:
#     118         # Tidy-up underlying socket on failure
#     119         self.close()
#
# File ~/miniforge3/envs/practice/lib/python3.10/site-packages/mysql/connector/abstracts.py:1052, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1049     self.config(**kwargs)
#    1051 self.disconnect()
# -> 1052 self._open_connection()
#    1053 # Server does not allow to run any other statement different from ALTER
#    1054 # when user's password has been expired.
#    1055 if not self._client_flags & ClientFlag.CAN_HANDLE_EXPIRED_PASSWORDS:
#
# File ~/miniforge3/envs/practice/lib/python3.10/site-packages/mysql/connector/connection.py:494, in MySQLConnection._open_connection(self)
#     492 self._socket = self._get_connection()
#     493 try:
# --> 494     self._socket.open_connection()
#     495     self._do_handshake()
#     496     self._do_auth(self._user, self._password,
#     497                   self._database, self._client_flags, self._charset_id,
#     498                   self._ssl, self._conn_attrs)
#
# File ~/miniforge3/envs/practice/lib/python3.10/site-packages/mysql/connector/network.py:565, in MySQLTCPSocket.open_connection(self)
#     563         addrinfo = addrinfos[0]
#     564 except IOError as err:
# --> 565     raise errors.InterfaceError(
#     566         errno=2003, values=(self.get_address(), _strioerror(err)))
#     567 else:
#     568     (self._family, socktype, proto, _, sockaddr) = addrinfo
#
# InterfaceError: 2003: Can't connect to MySQL server on '%-.100s:%u' (%s) (Warning: %u format: a real number is required, not str)

# %%
remote.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb 셀 16 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/newrandom/Documents/GitHub/MySQL/sql_ws/python.ipynb#ch0000021?line=0'>1</a> remote.close()
#
# NameError: name 'remote' is not defined
